# %% [markdown]
# <img src="Images/Ballenas_logo.jpg">
# # BSS Cube Satellite Payload: Environmental Data
# This notebook displays data collected from one of the Raspberry Pi 3 Model B's. This pi will be running the computational program and collecting environmental data from the pihat.

# %%
#import of libraries.
#this cell must be ran each time the notebook is started.
import pandas as pd
import numpy as np
from IPython.display import set_matplotlib_formats
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Static Test
# This static test will be compared to the data we collect during the rocket flight.
# #### Description of Computational Program
# To meet the desires of the science team, software devised a new computational program that would calculate a set equation while printing the time it took to calculate each time. The equation used is 'x^2' where x increases by 1 each time. The data will write to a single file, then after five minutes, it will begin writing to a new file.

# %%
# these next fews cells imports the following datafiles from the computational program
data0 = pd.read_csv('Datafiles/CompStatic/calcresults0.txt')
#data0.info()
data1 = pd.read_csv('Datafiles/CompStatic/calcresults1.txt')
#data3.info()
data2 = pd.read_csv('Datafiles/CompStatic/calcresults2.txt')
#data2.info()

# %%
datastatic = pd.concat([data0, data1, data2]) # this will combine the three datafiles into one
datastatic.info()

iterationstatic = datastatic['iteration'] # assign data to a variable to be called up later
timestatic = datastatic['time']
resultstatic = datastatic['result']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3158320 entries, 0 to 1052084
# Data columns (total 3 columns):
# iteration    int64
# time         float64
# result       int64
# dtypes: float64(1), int64(2)
# memory usage: 96.4 MB

# %%
#this cell plots the data as the result as a function of the iteration
plt.xlabel('Iteration')
plt.ylabel('Result')
plt.title('Result vs Iteration')
plt.plot(iterationstatic, resultstatic)

# %%
# will determine if the program properly calculated the equation by finding the last result and last iteration in the datafile
# and squaring the iteration to see if it equals the result
maxRs = max(resultstatic)
maxIs = max(iterationstatic)
maxTs = max(timestatic)
if max(resultstatic) == (max(iterationstatic)**2):
    print('Correct')
else:
    print('Program didnt properly calculate the equation')
# Out:
# Correct

# %%
# finding the time it took the program to write the amount of iterations
maxmins = maxTs/60
print('It took',maxTs,'seconds or',maxmins,'minutes to calculate', maxIs,'iterations.')
# Out:
# It took 900.000711441 seconds or 15.0000118574 minutes to calculate 3158319 iterations.

# %% [markdown]
# ## Computational Program Analysis
# The cells below will upload the files and analyze the data collected while also comparing it to the static test.

# %%
# these next fews cells imports the following datafiles from the computational program
#change the location name of the file folder
#add/remove however many files there is

data1 = pd.read_csv('Datafiles/Environ/calcresults1.txt')
#data1.info()

data2 = pd.read_csv('Datafiles/Environ/calcresults2.txt')
#data3.info()

data3 = pd.read_csv('Datafiles/Environ/calcresults3.txt')
#data3.info()

data4 = pd.read_csv('Datafiles/Environ/calcresults4.txt')
#data4.info()

data5 = pd.read_csv('Datafiles/Environ/calcresults5.txt')
#data5.info()

data6 = pd.read_csv('Datafiles/Environ/calcresults6.txt')
#data6.info()

data7 = pd.read_csv('Datafiles/Environ/calcresults7.txt')
#data7.info()

data8 = pd.read_csv('Datafiles/Environ/calcresults8.txt')
#data8.info()

data9 = pd.read_csv('Datafiles/Environ/calcresults9.txt')
#data9.info()

data10 = pd.read_csv('Datafiles/Environ/calcresults10.txt')
#data10.info()

data11 = pd.read_csv('Datafiles/Environ/calcresults11.txt')
#data11.info()

# %%
# this will combine all the datafiles into one
dataC = pd.concat([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11]) 
dataC.info()
iterationC = dataC['iteration'] # assign data to a variable to be called up later
timeC = dataC['time']
resultC = dataC['result']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10311336 entries, 0 to 390979
# Data columns (total 3 columns):
# iteration    int64
# time         float64
# result       float64
# dtypes: float64(2), int64(1)
# memory usage: 314.7 MB

# %%
#this cell plots the data as the result as a function of the iteration
plt.xlabel('Iteration')
plt.ylabel('Result')
plt.title('Result vs Iteration')
plt.plot(iterationC, resultC)

# %%
# this cell plots result vs time
plt.xlabel('Time')
plt.ylabel('Result')
plt.title('Result vs Time')
plt.plot(timeC, resultC)

# %%
# this cell plots iteration vs time
plt.xlabel('Time')
plt.ylabel('Iteration')
plt.title('Iteration vs Time')
plt.plot(timeC, iterationC)

# %%
# will determine if the program properly calculated the equation by finding the last result and last iteration in the datafile
# and squaring the iteration to see if it equals the result
maxR = max(resultC)
maxI = max(iterationC)
maxT = max(timeC)
if max(resultC) == (max(iterationC-1)**2): # taking the second last iteration may be necessary because
    print('Correct')                     # the very last iteration didn't write to the file
else:
    print('Program didnt properly calculate the equation')
# Out:
# Correct

# %%
# finding the time it took the program to write the amount of iterations
maxmin = maxT/60
print('It took',maxT,'seconds or',maxmin,'minutes to calculate', maxI,'iterations.')
# Out:
# It took 3132.2247 seconds or 52.203745 minutes to calculate 10311335 iterations.

# %%
# this cell will compare the amount of time it took to calculate the equation to the static
staticC = (maxTs/maxIs)*100000
testC = (maxT/maxI)*100000
print('The static test calculated 100,000 iterations in',staticC,'seconds while the pi from the satellite did so in', testC,'seconds.')
# Out:
# The static test calculated 100,000 iterations in 28.4961940653 seconds while the pi from the satellite did so in 30.3765196262 seconds.

# %% [markdown]
# ## Environmental Data Analysis

# %%
#this cell imports the txt data file and displays its information to ensure all data has been included.
dataE = pd.read_csv('Datafiles/Environ/ScienceData0.txt')
dataE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32233 entries, 0 to 32232
# Data columns (total 13 columns):
# time        32232 non-null float64
# accelz      32232 non-null float64
# accely      32232 non-null float64
# accelx      32232 non-null float64
# gyroz       32232 non-null float64
# gyroy       32232 non-null float64
# gyrox       32232 non-null float64
# compassz    32232 non-null float64
# compassy    32232 non-null float64
# compassx    32232 non-null float64
# temp        32232 non-null float64
# pressure    32232 non-null float64
# humidity    32232 non-null float64
# dtypes: float64(13)
# memory usage: 3.2 MB

# %%
# assigns the data to a variable that can be called up later
timeE = dataE['time']
accelz = dataE['accelz']
accelx = dataE['accelx']
accely = dataE['accely']
gyroz = dataE['gyroz']
gyrox = dataE['gyrox']
gyroy = dataE['gyroy']
compassz = dataE['compassz']
compassx = dataE['compassx']
compassy = dataE['compassy']
temp = dataE['temp']
pressure = dataE['pressure']
humidity = dataE['humidity']

# %% [markdown]
# ### Analytic Graphing

# %%
# plotting accel vs time
fig, ((plot1, plot2), (plot3, plot4))=plt.subplots(2,2, figsize=(12, 8))
plot1.set_xlabel('time')
plot1.set_ylabel('accel z-axis')
plot1.set_title('Accel z-axis vs Time Data')
plot1.plot(timeE, accelz)

plot2.set_xlabel('time')
plot2.set_ylabel('accel x-axis')
plot2.set_title('Accel x-axis vs Time Data')
plot2.plot(timeE, accelx)   

plot3.set_xlabel('time')
plot3.set_ylabel('accel y-axis')
plot3.set_title('Accel y-axis vs Time Data')
plot3.plot(timeE, accely)
      
fig.tight_layout()
plt.show()

# %%
#plotting interactive 3D graph of acceleration with pandas

# %matplotlib notebook

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlabel('accelx')
ax.set_ylabel('accely')
ax.set_zlabel('accelz')
plt.title('acceleration vs time')

min_x = min(accelx)  # Find the minimum x value
min_y = accely[accelx.argmin()] # Find the y value corresponding to the minimum x value
min_z = accelz[accelx.argmin()] # Find the z value corresponding to the minimum x value

min_y1 = min(accely)  # Find the minimum y value
min_x1 = accelx[accely.argmin()] # Find the x value corresponding to the minimum y value
min_z1 = accelz[accely.argmin()] # Find the z value corresponding to the minimum y value

min_z2 = min(accelz)  # Find the minimum z value
min_x2 = accelx[accelz.argmin()] # Find the x value corresponding to the minimum z value
min_y2 = accely[accelz.argmin()] # Find the y value corresponding to the minimum z value

ax.plot(accelx, accely, accelz, label = 'acceleration')
ax.scatter(min_x, min_y, min_z, s=25, color='orange',label='min accelx')
ax.scatter(min_x1, min_y1, min_z1, s=25, color='red',label='min accely')
ax.scatter(min_x2, min_y2, min_z2, s=25, color='green',label='min accelz')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# below outputs a table with the time at which the minimum acceleration occured
Ad = {'Axis': ['x', 'y', 'z'],'Min Accel': [min_x, min_y1, min_z2],'Time': [timeE[accelx.argmin()], timeE[accely.argmin()], timeE[accelz.argmin()]]}
Acceldf = pd.DataFrame(data=Ad)
Acceldf
# Out:
#   Axis  Min Accel        Time
# 0    x   0.936811   16.296781
# 1    y  -0.142806   50.055938
# 2    z  -0.110391  652.333235

# %%
#plotting interactive 3D graph of acceleration with pandas

# %matplotlib notebook

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlabel('accelx')
ax.set_ylabel('accely')
ax.set_zlabel('accelz')
plt.title('acceleration vs time')

max_x = max(accelx)  # Find the maximum x value
max_y = accely[accelx.argmax()] # Find the y value corresponding to the maximum x value
max_z = accelz[accelx.argmax()] # Find the z value corresponding to the maximum x value

max_y1 = max(accely)  # Find the maximum y value
max_x1 = accelx[accely.argmax()] # Find the x value corresponding to the maximum y value
max_z1 = accelz[accely.argmax()] # Find the z value corresponding to the maximum y value

max_z2 = max(accelz)  # Find the maximum z value
max_x2 = accelx[accelz.argmax()] # Find the x value corresponding to the maximum z value
max_y2 = accely[accelz.argmax()] # Find the y value corresponding to the maximum z value

ax.plot(accelx, accely, accelz, label = 'acceleration')
ax.scatter(max_x, max_y, max_z, s=25, color='orange',label='max accelx')
ax.scatter(max_x1, max_y1, max_z1, s=25, color='red',label='max accely')
ax.scatter(max_x2, max_y2, max_z2, s=25, color='green',label='max accelz')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# below outputs a table with the time at which the minimum acceleration occured
maxA = {'Axis': ['x', 'y', 'z'],'Max Accel': [max_x, max_y1, max_z2],'Time': [timeE[accelx.argmax()], timeE[accely.argmax()], timeE[accelz.argmax()]]}
maxAdf = pd.DataFrame(data=maxA)
maxAdf
# Out:
#   Axis  Max Accel        Time
# 0    x   1.130283  103.138787
# 1    y   0.193506   29.317388
# 2    z   0.153529    0.163574

# %%
# plotting gyro vs time
# %matplotlib inline
fig, ((plot5, plot6), (plot7, plot4))=plt.subplots(2,2, figsize=(12, 8))
plot5.set_xlabel('time')
plot5.set_ylabel('Gyro z-axis')
plot5.set_title('Gyro z-axis vs Time Data')
plot5.plot(timeE, gyroz)

plot6.set_xlabel('time')
plot6.set_ylabel('Gyro x-axis')
plot6.set_title('Gyro x-axis vs Time Data')
plot6.plot(timeE, gyrox)   

plot7.set_xlabel('time')
plot7.set_ylabel('Gyro y-axis')
plot7.set_title('Gyro y-axis vs Time Data')
plot7.plot(timeE, gyroy)
      
fig.tight_layout()
plt.show()

# %%
#plotting interactive 3D graph of gyro with min. points

# %matplotlib notebook

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlabel('gyrox')
ax.set_ylabel('gyroy')
ax.set_zlabel('gyroz')
plt.title('gyro vs time')

min_xg = min(gyrox)  # Find the minimum x value
min_yg = gyroy[gyrox.argmin()] # Find the y value corresponding to the minimum x value
min_zg = gyroz[gyrox.argmin()] # Find the z value corresponding to the minimum x value

min_y1g = min(gyroy)  # Find the minimum y value
min_x1g = gyrox[gyroy.argmin()] # Find the x value corresponding to the minimum y value
min_z1g = gyroz[gyroy.argmin()] # Find the z value corresponding to the minimum y value

min_z2g = min(gyroz)  # Find the minimum z value
min_x2g = gyrox[gyroz.argmin()] # Find the x value corresponding to the minimum z value
min_y2g = gyroy[gyroz.argmin()] # Find the y value corresponding to the minimum z value

ax.plot(gyrox, gyroy, gyroz, label = 'gyro')
ax.scatter(min_xg, min_yg, min_zg, s=25, color='orange',label='min gyrox')
ax.scatter(min_x1g, min_y1g, min_z1g, s=25, color='red',label='min gyroy')
ax.scatter(min_x2g, min_y2g, min_z2g, s=25, color='green',label='min gyroz')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# below outputs a table with the time at which the maximum acceleration occured
Gmin = {'Axis': ['x', 'y', 'z'],'Min Gyro': [min_xg, min_y1g, min_z2g],'Time': [timeE[gyrox.argmin()], timeE[gyroy.argmin()], timeE[gyroz.argmin()]]}
Gyrodfmin = pd.DataFrame(data=Gmin)
Gyrodfmin
# Out:
#   Axis  Min Gyro       Time
# 0    x -0.624817  28.192370
# 1    y -0.082528  26.879655
# 2    z -0.926987   0.163574

# %%
#plotting interactive 3D graph of gyro with max. points

# %matplotlib notebook

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlabel('gyrox')
ax.set_ylabel('gyroy')
ax.set_zlabel('gyroz')
plt.title('gyro vs time')

max_xg = max(gyrox)  # Find the maximum x value
max_yg = gyroy[gyrox.argmax()] # Find the y value corresponding to the maximum x value
max_zg = gyroz[gyrox.argmax()] # Find the z value corresponding to the maximum x value

max_y1g = max(gyroy)  # Find the maximum y value
max_x1g = gyrox[gyroy.argmax()] # Find the x value corresponding to the maximum y value
max_z1g = gyroz[gyroy.argmax()] # Find the z value corresponding to the maximum y value

max_z2g = max(gyroz)  # Find the maximum z value
max_x2g = gyrox[gyroz.argmax()] # Find the x value corresponding to the maximum z value
max_y2g = gyroy[gyroz.argmax()] # Find the y value corresponding to the maximum z value

ax.plot(gyrox, gyroy, gyroz, label = 'gyro')
ax.scatter(max_xg, max_yg, max_zg, s=25, color='orange',label='max gyrox')
ax.scatter(max_x1g, max_y1g, max_z1g, s=25, color='red',label='max gyroy')
ax.scatter(max_x2g, max_y2g, max_z2g, s=25, color='green',label='max gyroz')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# below outputs a table with the time at which the maximum acceleration occured
Gmax = {'Axis': ['x', 'y', 'z'],'Max Gyro': [max_xg, max_y1g, max_z2g],'Time': [timeE[gyrox.argmax()], timeE[gyroy.argmax()], timeE[gyroz.argmax()]]}
Gyrodfmax = pd.DataFrame(data=Gmax)
Gyrodfmax
# Out:
#   Axis  Max Gyro       Time
# 0    x  1.212194   0.163574
# 1    y  0.827302   0.163574
# 2    z  0.217132  14.695437

# %%
# plotting temp, pressure and humidity vs time
# %matplotlib inline
fig, ((plot8, plot9), (plot0, plot4))=plt.subplots(2,2, figsize=(12, 8))
plot8.set_xlabel('time')
plot8.set_ylabel('temp')
plot8.set_title('Temp vs Time Data')
plot8.plot(timeE, temp)

plot9.set_xlabel('time')
plot9.set_ylabel('pressure')
plot9.set_title('Pressure vs Time Data')
plot9.plot(timeE, pressure)   

plot0.set_xlabel('time')
plot0.set_ylabel('humidity')
plot0.set_title('Humidity vs Time Data')
plot0.plot(timeE, humidity)
      
fig.tight_layout()
plt.show()

# %%
#plotting interactive 3D graph of acceleration with min and max temp, min and max pressure, and min and max humidity

# %matplotlib notebook

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlabel('accelx')
ax.set_ylabel('accely')
ax.set_zlabel('accelz')
plt.title('acceleration vs time')

min_t = min(temp)
min_xt = accelx[temp.argmin()] # Find the x accel value corresponding to the minimum temp value
min_yt = accely[temp.argmin()] # Find the y accel value corresponding to the minimum temp value
min_zt = accelz[temp.argmin()] # Find the z accel value corresponding to the minimum temp value

max_t = max(temp)
max_xt = accelx[temp.argmax()] # Find the x accel value corresponding to the maximum temp value
max_yt = accely[temp.argmax()] # Find the y accel value corresponding to the maximum temp value
max_zt = accelz[temp.argmax()] # Find the z accel value corresponding to the maximum temp value

# remove the hashtags to plot min and max points for pressure and humidity
min_p = min(pressure)
#min_xp = accelx[pressure.argmin()]
#min_yp = accely[pressure.argmin()]
#min_zp = accelz[pressure.argmin()]

max_p = max(pressure)
#max_xp = accelx[pressure.argmax()]
#max_yp = accely[pressure.argmax()]
#max_zp = accelz[pressure.argmax()]

min_h = min(humidity)
#min_xh = accelx[humidity.argmin()]
#min_yh = accely[humidity.argmin()]
#min_zh = accelz[humidity.argmin()]

max_h = max(humidity)
#max_xh = accelx[humidity.argmax()]
#max_yh = accely[humidity.argmax()]
#max_zh = accelz[humidity.argmax()]

ax.plot(accelx, accely, accelz, label = 'acceleration') # plots the acceleration
ax.scatter(min_xt, min_yt, min_zt, s=25, color='red',label='min temp') # plots the point at which min. temp occurred
ax.scatter(max_xt, max_yt, max_zt, s=25, color='green',label='max temp') # plots the point at which max. temp occurred
#ax.scatter(min_xp, min_yp, min_zp, s=25, color='orange', label='min pressure')
#ax.scatter(max_xp, max_yp, max_zp, s=25, color='yellow', label='max pressure')
#ax.scatter(min_xh, min_yh, min_zh, s=25, color='orange', label='min humidity')
#ax.scatter(max_xh, max_yh, max_zh, s=25, color='yellow', label='max humidity')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ### Comparing Max., Min. and Average Values
# By finding and comparing the maximum values of the data collected, (temp, accel, gyro, humidity, etc...), we can determine where the pi experienced the most amount of stress during the launch. This where we can focus our more thorough data analytics to see if any failures occurred or if the didn't function to its full capability and why. Finding the minimum value and average of the data will allow us to determine if the maximum value found, is truly an extreme value or comparable the rest of the data.

# %%
# this will make a data table that will display max. values for all data with their corresponding times

# first we have to find the time corresponding to each min and max value
timemax_x = timeE[accelx.argmax()]
timemax_y1 = timeE[accely.argmax()]
timemax_z2 = timeE[accelz.argmax()]
timemax_xg = timeE[gyrox.argmax()]
timemax_y1g = timeE[gyroy.argmax()]
timemax_z2g = timeE[gyroz.argmax()]
timemax_t = timeE[temp.argmax()]
timemax_p = timeE[pressure.argmax()]
timemax_h = timeE[humidity.argmax()]

timemin_x = timeE[accelx.argmin()]
timemin_y1 = timeE[accely.argmin()]
timemin_z2 = timeE[accelz.argmin()]
timemin_xg = timeE[gyrox.argmin()]
timemin_y1g = timeE[gyroy.argmin()]
timemin_z2g = timeE[gyroz.argmin()]
timemin_t = timeE[temp.argmin()]
timemin_p = timeE[pressure.argmin()]
timemin_h = timeE[humidity.argmin()]

d = {'Environ': ['accelx','accely','accelz','gyrox','gyroy','gyroz','temp','pressure','humidity'],'Max.': [max_x, max_y1, max_z2, max_xg, max_y1g, max_z2g, max_t, max_p, max_h], 'Max. Time (sec)': [timemax_x, timemax_y1, timemax_z2, timemax_xg, timemax_y1g, timemax_z2g, timemax_t, timemax_p, timemax_h], 'Min': [min_x, min_y1, min_z2, min_xg, min_y1g, min_z2g, min_t, min_p, min_h], 'Min. Time (sec)': [timemin_x, timemin_y1, timemin_z2, timemin_xg, timemin_y1g, timemin_z2g, timemin_t, timemin_p, timemin_h]}
df = pd.DataFrame(data=d)
df
# Out:
#     Environ         Max.  Max. Time (sec)        Min  Min. Time (sec)
# 0    accelx     1.130283       103.138787   0.936811        16.296781
# 1    accely     0.193506        29.317388  -0.142806        50.055938
# 2    accelz     0.153529         0.163574  -0.110391       652.333235
# 3     gyrox     1.212194         0.163574  -0.624817        28.192370
# 4     gyroy     0.827302         0.163574  -0.082528        26.879655
# 5     gyroz     0.217132        14.695437  -0.926987         0.163574
# 6      temp    40.035943      2911.723115  11.885333         0.163574
# 7  pressure  1025.589844         0.256222   0.000000         0.163574
# 8  humidity    62.675308         0.448084  23.593750      2166.174801
